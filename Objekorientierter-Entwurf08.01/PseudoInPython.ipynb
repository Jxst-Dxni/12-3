# %%
class idxGefundenerLp:
    idxGefundenerLp = -1
    gefunden = falsch
    If idx = 0 bis aAnz -1, SW1
        name = DerLagerplatz[idx].gibArtikelname()
    
else:
    name = pArtikelname
    gefunden = wahr
