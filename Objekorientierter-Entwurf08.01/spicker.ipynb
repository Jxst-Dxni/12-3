# %% [markdown]
# ### Installationen
# Mann muss zu erst flask importieren und auch schreiben was man davon braucht,
# im Terminal macht man die pip install.
# import json,
# import os,
# from flask_cors import CORS
#
# app = Flask(__name__)
# CORS(app)

# %% [markdown]
# ### BaseModel
# Man macht ein "Basemodel" in einer extra Datei. Am Anfang schreibt man `from pydantic import Basemodel, Field`.
# Darunter macht man die Klasse und fügt eigenschaften der KLasse darunter ein.
# Bsp: Name: str(str=erwarteter Datentyp) = Field(default="Felix") (Bei zahlen z.b. Jahrgang muss man min und max angeben, das macht man mit ge(minimum)und le(maximum)).

# %% [markdown]
# ### Client
# Am Anfang macht man import request.
# Dann kommt die server_url = 'http://localhost:12345/message'
# Man macht eine while-Schleife,
# dann kommt nachricht vom Benutzer/ danach kommt Nachricht an den server senden.
# Zuletzt kommt die server antwort mit if/else.      (für die server message)

# %% [markdown]
# ### Client2 (Für den Spieler)
# Man import request/json
# dann kommt die URL = "http://127.0.0.1:12345/Spieler"
# Dann kommen die daten die wir im Model gemacht haben.
# ```python
# response = requests.post(URL, json=spieler_daten)
# print("Statuscode:", response.status_code)
# ```
# Dann kommt wieder if response.status_code == 201:
# else:

# %% [markdown]
# ### Server
# @app.route('/')
# def home():
#     return
# allgemein zum starten einer Route
#
# # Route zum Empfangen von Nachrichten
# ```python
# @app.route('/message', methods=['POST'])
# def handle_message():
#     data = request.json
#     message = data.get('message', '')
#     print(f"Empfangen: {message}")
#     response_message = f"Echo: {message}"
#     attributes()
#     return jsonify({"response": response_message})
# ```
#
# dann muss man die attributes(): definieren
# return f'''
#
# dannach kommt die spieler_liste = []
#
# methods=[POST] schickt was zurück
# GET = server zieht sich was

# %% [markdown]
# bei def atributes kommt danach eingerückt:
# return f''' und am ende '''
